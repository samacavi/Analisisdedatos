# %%
2+4
# Out:
# 6

# %%
5+8
# Out:
# 13

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("hasta luego, mundo")
# Out:
# hasta luego, mundo

# %%
variable_Carro= 20
variable_Carro2= 30

print(variable_Carro + variable_Carro2)
# Out:
# 50
